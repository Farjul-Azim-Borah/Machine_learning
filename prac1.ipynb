# %% [markdown]
# <a href="https://colab.research.google.com/github/Farjul-Azim-Borah/Machine_learning/blob/main/prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'] , df['iq'] , c = df['placement'])

# %%
X = df.iloc[:, 0:2]
Y = df.iloc[:, -1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X,Y,test_size = 0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 80   4.9  196.0
# 62   6.0  102.0
# 26   7.0  199.0
# 97   6.7  182.0
# 36   5.7  140.0
# ..   ...    ...
# 95   4.3  200.0
# 33   6.0  149.0
# 70   6.3  127.0
# 49   5.4  135.0
# 27   6.0  124.0
#
# [90 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-9.89468729e-01,  1.79480074e+00],
#        [-9.89468729e-03, -5.45161390e-01],
#        [ 8.80627169e-01,  1.86948038e+00],
#        [ 6.13470612e-01,  1.44629574e+00],
#        [-2.77051244e-01,  4.00780748e-01],
#        [ 7.91574983e-02, -1.46621031e+00],
#        [-2.77051244e-01,  2.01635035e-01],
#        [-7.22312172e-01,  9.23538245e-01],
#        [-1.43472966e+00,  6.24819675e-01],
#        [ 7.91574983e-01, -6.94520675e-01],
#        [ 1.59304465e+00, -2.46442820e-01],
#        [-1.25662529e+00,  5.50140033e-01],
#        [ 1.14778373e+00,  3.26101105e-01],
#        [ 1.32588810e+00,  8.48858603e-01],
#        [-5.44207801e-01, -2.46442820e-01],
#        [-9.89468729e-01,  7.74178960e-01],
#        [-2.41430370e+00,  1.47118896e+00],
#        [ 9.69679354e-01, -1.88939495e+00],
#        [ 1.14778373e+00, -1.83960853e+00],
#        [ 3.46314055e-01, -1.96656392e-01],
#        [-1.16757310e+00, -9.18559602e-01],
#        [ 1.32588810e+00,  1.51848606e-01],
# ...

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-0.81136436,  1.29693646],
#        [-1.07852091, -0.29622925],
#        [ 0.79157498,  0.35099432],
#        [ 0.25726187, -0.52026818],
#        [-0.72231217, -0.84387996],
#        [ 0.0791575 ,  0.79907217],
#        [ 2.21640995, -0.09708354],
#        [-1.7909384 , -0.59494782],
#        [ 0.43536624,  0.89864503],
#        [-1.1675731 , -1.7898221 ]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train , Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test , y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, Y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >
