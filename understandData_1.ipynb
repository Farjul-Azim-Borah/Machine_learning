# %% [markdown]
# <a href="https://colab.research.google.com/github/Farjul-Azim-Borah/Machine_learning/blob/main/understandData_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %%
# 1. Know the shape of the data

df.shape
# Out:
# (891, 12)

# %%
# data dikhta kaisa hai --- see some random values
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 720          721         1       2  Harper, Miss. Annie Jessie "Nina"  female
# 812          813         0       2          Slemen, Mr. Richard James    male
# 562          563         0       2         Norman, Mr. Robert Douglas    male
# 244          245         0       3               Attalah, Mr. Sleiman    male
# 769          770         0       3   Gronnestad, Mr. Daniel Danielsen    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 720   6.0      0      1  248727  33.0000   NaN        S
# 812  35.0      0      0   28206  10.5000   NaN        S
# 562  28.0      0      0  218629  13.5000   NaN        S
# 244  30.0      0      0    2694   7.2250   NaN        C
# 769  32.0      0      0    8471   8.3625   NaN        S

# %%
# know about the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# know the number of missing values in a column
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# is there duplicate values
df.duplicated().sum()
# Out:
# 0

# %%
# how does two column is correlated
df_encoded = pd.get_dummies(df, drop_first=True)
df_encoded.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
#                  ...
# Cabin_F4       0.060095
# Cabin_G6       0.016040
# Cabin_T       -0.026456
# Embarked_Q     0.003650
# Embarked_S    -0.155660
# Name: Survived, Length: 1726, dtype: float64
